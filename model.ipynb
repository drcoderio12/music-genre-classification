# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt

# %%
data_path = r"C:\Users\mohammed kaif\Downloads\archive\Data\features_3_sec.csv"
df_main = pd.read_csv(data_path)

# %%
df_main.shape
X = df_main.drop('label',axis=1)
y = df_main['label']

# %%
#encoding the labels for future referencing
index_map = ['blues','classical','country','disco','hiphop','jazz','metal','pop','reggae','rock']
genre_map = {'blues':0,
             'classical':1,
            'country': 2,
            'disco': 3,
            'hiphop':4,
            'jazz':5,
            'metal':6,
            'pop':7,
            'reggae':8,
            'rock':9}


for i in range(len(y)):
    y[i] = genre_map[y[i]]
    
y = y.astype(int)
# Out:
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# ...
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\4226296203.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = genre_map[y[i]]

# %%
X = X.drop(['filename','length','harmony_mean','harmony_var','perceptr_mean','perceptr_var'],axis = 1)
X.shape
# Out:
# (9990, 53)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_rem, y_train, y_rem = train_test_split(X,y,stratify = y, test_size = 0.15)
X_test, X_val, y_test, y_val = train_test_split(X_rem, y_rem , stratify = y_rem , test_size = 0.5)
print(X_train.shape )
print(X_val.shape)
# Out:
# (8491, 53)
# (750, 53)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)
X_val = sc.transform(X_val)

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC
SVM_classifier = SVC(kernel = 'poly',C =0.1,gamma = 1)
SVM_classifier.fit(X_train,y_train)
# Out:
# SVC(C=0.1, gamma=1, kernel='poly')

# %%
y_pred = SVM_classifier.predict(X_val)
y_pred
# Out:
# array([9, 6, 2, 5, 6, 5, 0, 1, 7, 2, 9, 2, 5, 5, 7, 9, 1, 6, 3, 1, 6, 5,
#        1, 6, 8, 1, 2, 6, 2, 4, 3, 9, 8, 3, 7, 9, 2, 1, 2, 4, 2, 1, 9, 6,
#        0, 2, 3, 1, 1, 3, 8, 4, 1, 3, 0, 7, 8, 6, 0, 0, 1, 9, 2, 4, 8, 6,
#        0, 2, 3, 2, 8, 1, 8, 7, 3, 8, 0, 2, 2, 8, 5, 9, 6, 8, 3, 3, 7, 6,
#        3, 0, 4, 5, 3, 6, 4, 5, 9, 8, 1, 1, 5, 0, 0, 4, 0, 8, 6, 2, 2, 2,
#        2, 0, 1, 5, 9, 2, 9, 5, 6, 9, 5, 3, 2, 4, 6, 5, 1, 7, 9, 4, 5, 7,
#        3, 8, 7, 9, 3, 7, 4, 8, 5, 7, 4, 4, 5, 7, 2, 2, 7, 6, 1, 0, 0, 8,
#        7, 7, 7, 1, 9, 4, 2, 7, 8, 6, 3, 1, 4, 0, 8, 3, 4, 3, 5, 3, 6, 5,
#        9, 1, 5, 8, 9, 2, 9, 9, 8, 3, 4, 0, 7, 5, 7, 0, 5, 1, 1, 2, 1, 4,
#        4, 4, 7, 4, 3, 9, 7, 6, 0, 5, 8, 3, 6, 4, 8, 1, 9, 3, 6, 5, 5, 1,
#        1, 2, 0, 0, 7, 4, 2, 8, 6, 2, 6, 8, 0, 5, 9, 7, 1, 6, 2, 5, 8, 4,
#        7, 3, 6, 8, 8, 3, 5, 8, 1, 1, 3, 0, 3, 3, 1, 8, 6, 6, 7, 6, 6, 3,
#        7, 4, 1, 0, 4, 2, 7, 8, 6, 3, 8, 0, 5, 8, 5, 4, 2, 9, 3, 1, 9, 3,
#        6, 4, 0, 1, 8, 9, 7, 3, 6, 6, 3, 8, 3, 0, 7, 3, 1, 3, 6, 0, 6, 8,
#        5, 2, 9, 3, 1, 0, 5, 2, 2, 6, 9, 4, 5, 3, 9, 1, 6, 2, 0, 8, 2, 1,
#        5, 2, 1, 2, 5, 1, 2, 0, 0, 0, 3, 4, 6, 6, 7, 3, 1, 3, 7, 7, 9, 6,
#        7, 8, 8, 5, 5, 5, 1, 2, 0, 7, 4, 8, 9, 4, 0, 3, 2, 7, 7, 0, 6, 4,
#        9, 9, 1, 6, 7, 0, 3, 6, 0, 7, 7, 3, 0, 3, 7, 6, 4, 5, 7, 3, 4, 7,
#        9, 7, 0, 9, 6, 1, 6, 7, 8, 9, 9, 2, 7, 7, 0, 3, 9, 1, 4, 0, 9, 8,
#        2, 5, 5, 5, 0, 1, 6, 2, 6, 4, 4, 7, 8, 3, 6, 7, 6, 2, 8, 2, 2, 6,
#        5, 5, 3, 0, 4, 7, 2, 3, 2, 4, 1, 0, 8, 0, 6, 2, 6, 1, 3, 0, 3, 0,
#        2, 5, 9, 5, 6, 6, 2, 6, 7, 5, 1, 4, 4, 4, 1, 8, 8, 8, 1, 4, 0, 8,
#        1, 2, 4, 3, 5, 9, 2, 3, 4, 1, 4, 2, 8, 9, 8, 1, 5, 3, 8, 0, 1, 9,
#        8, 9, 9, 0, 8, 5, 4, 4, 1, 7, 5, 3, 3, 6, 8, 4, 5, 3, 9, 1, 3, 4,
#        0, 3, 8, 1, 6, 9, 6, 5, 6, 0, 6, 6, 9, 4, 5, 2, 4, 0, 0, 8, 1, 6,
#        3, 3, 0, 3, 7, 1, 2, 0, 3, 4, 6, 3, 4, 4, 3, 4, 3, 8, 1, 8, 3, 9,
#        4, 5, 0, 8, 2, 3, 8, 0, 2, 6, 2, 2, 0, 9, 2, 8, 7, 7, 2, 8, 7, 2,
#        4, 8, 0, 1, 7, 5, 9, 1, 7, 6, 5, 8, 3, 5, 7, 4, 1, 3, 0, 3, 2, 0,
#        4, 3, 8, 6, 7, 8, 8, 2, 0, 7, 1, 7, 4, 4, 2, 5, 1, 8, 0, 6, 8, 0,
#        2, 9, 7, 9, 8, 1, 7, 2, 8, 2, 3, 0, 5, 2, 8, 1, 1, 4, 0, 5, 1, 5,
#        2, 1, 5, 2, 7, 1, 1, 6, 0, 0, 2, 9, 7, 6, 2, 2, 7, 2, 0, 1, 9, 5,
#        4, 8, 3, 3, 6, 9, 5, 2, 7, 2, 4, 5, 2, 7, 0, 3, 5, 4, 9, 1, 8, 7,
#        5, 0, 1, 7, 7, 4, 9, 9, 5, 7, 8, 8, 4, 2, 0, 0, 3, 8, 1, 9, 3, 0,
#        9, 6, 8, 3, 1, 4, 8, 4, 3, 2, 3, 8, 9, 8, 8, 5, 9, 5, 2, 6, 3, 6,
#        6, 1])

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_val,y_pred)
cm


print('accuracy score: ', accuracy_score(y_val,y_pred))
print('f1_score : ', f1_score(y_val,y_pred,average='micro'))
# Out:
# accuracy score:  0.8893333333333333
# f1_score :  0.8893333333333333

# %% [markdown]
# # GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

#defining parameter range
param_grid = {'C' : [0.1,1,10],
             'gamma': [1, 0.1],
             'kernel': ['rbf','poly']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)


history_svm = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.157 total time=   8.5s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.143 total time=   8.3s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.157 total time=   8.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.138 total time=   8.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.151 total time=   8.2s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.868 total time=   2.2s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.862 total time=   2.3s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.858 total time=   3.8s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.867 total time=   4.6s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.878 total time=   4.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.458 total time=   7.4s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.478 total time=   8.4s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.433 total time=   8.2s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.462 total time=   8.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.467 total time=   8.2s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.873 total time=   2.6s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.868 total time=   2.5s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.856 total time=   2.1s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.860 total time=   2.4s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.871 total time=   2.4s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.245 total time=  10.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.245 total time=   9.5s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.260 total time=   9.9s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.246 total time=   8.1s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.264 total time=   8.2s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.868 total time=   2.0s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.862 total time=   2.1s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.858 total time=   1.9s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.867 total time=   2.2s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.878 total time=   2.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.822 total time=   6.9s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.840 total time=   8.2s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.819 total time=   8.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.833 total time=   8.1s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.824 total time=   8.0s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.869 total time=   2.5s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.862 total time=   2.1s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.859 total time=   2.5s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.867 total time=   2.3s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.878 total time=   2.3s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.267 total time=   9.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.267 total time=   8.4s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.289 total time=   7.8s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.271 total time=   7.6s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.288 total time=   8.1s
# [CV 1/5] END ........C=10, gamma=1, kernel=poly;, score=0.868 total time=   1.8s
# [CV 2/5] END ........C=10, gamma=1, kernel=poly;, score=0.862 total time=   1.9s
# [CV 3/5] END ........C=10, gamma=1, kernel=poly;, score=0.858 total time=   1.8s
# [CV 4/5] END ........C=10, gamma=1, kernel=poly;, score=0.867 total time=   1.9s
# [CV 5/5] END ........C=10, gamma=1, kernel=poly;, score=0.878 total time=   1.9s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.840 total time=   7.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.857 total time=   8.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.837 total time=   7.5s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.856 total time=  12.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.842 total time=  17.2s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.868 total time=   2.1s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.862 total time=   2.0s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.858 total time=   1.9s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.867 total time=   2.0s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.878 total time=   2.3s

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'poly'}
# SVC(C=1, gamma=0.1, kernel='poly')

# %%
grid_predictions = grid.predict(X_val)
print('accuracy score: ', accuracy_score(y_val,grid_predictions))
print('f1_score : ', f1_score(y_val,grid_predictions,average='micro'))
# Out:
# accuracy score:  0.8893333333333333
# f1_score :  0.8893333333333333

# %% [markdown]
# # Metadata Generator

# %%
import librosa
def getdataf(filename):
    


    y, sr = librosa.load(filename)
    #fetching tempo

    onset_env = librosa.onset.onset_strength(y=y, sr=sr)
    tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr)

    #fetching beats

    y_harmonic, y_percussive = librosa.effects.hpss(y)
    tempo, beat_frames = librosa.beat.beat_track(y=y_percussive,sr=sr)

    #chroma_stft

    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)

    #rmse

    rmse = librosa.feature.rms(y=y)

    #fetching spectral centroid

    spec_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)[0]

    #spectral bandwidth

    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)

    #fetching spectral rolloff

    spec_rolloff = librosa.feature.spectral_rolloff(y=y+0.01, sr=sr)[0]

    #zero crossing rate

    zero_crossing = librosa.feature.zero_crossing_rate(y)
#     harmonics = [1./3, 1./2, 1, 2, 3, 4]
#     S = np.abs(librosa.stft(y))
#     fft_freqs = librosa.fft_frequencies(sr=sr)
#     S_harm = librosa.interp_harmonics(S, freqs=fft_freqs, harmonics=harmonics, axis=0)
#     S = np.abs(librosa.stft(y))
#     fft_freqs = librosa.fft_frequencies(sr=sr)
#     t_harmonics = librosa.interp_harmonics(S, freqs=fft_freqs, harmonics=harmonics, axis=0)
    
#     C = np.abs(librosa.cqt(y, sr=sr, fmin=librosa.note_to_hz('A1')))
#     freqs = librosa.cqt_frequencies(C.shape[0],
#                                 fmin=librosa.note_to_hz('A1'))
#     perceptual_CQT = librosa.perceptual_weighting(C**2,
#                                               freqs,
#                                               ref=np.max)
    #mfcc

    mfcc = librosa.feature.mfcc(y=y, sr=sr)

    #metadata dictionary

    metadata_dict = {'chroma_stft_mean':np.mean(chroma_stft),'chroma_stft_var':np.var(chroma_stft),'rmse_mean':np.mean(rmse),'rmse_var':np.var(rmse),
                     'spectral_centroid_mean':np.mean(spec_centroid),'spectral_centroid_var':np.var(spec_centroid),'spectral_bandwidth_mean':np.mean(spec_bw),'spectral_bandwidth':np.var(spec_bw), 
                     'rolloff_mean':np.mean(spec_rolloff),'rolloff_var':np.var(spec_rolloff), 'zero_crossing_rate_mean':np.mean(zero_crossing),'zero_crossing_rate_var':np.var(zero_crossing),
                    # 'harmony_mean':np.mean(t_harmonics),'harmony_var':np.var(t_harmonics),
                    # 'perceptr_mean':np.mean(perceptual_CQT),'perceptr_var':np.var(perceptual_CQT),
                     'tempo':tempo}

    for i in range(1,21):
        metadata_dict.update({'mfcc'+str(i)+'_mean':np.mean(mfcc[i-1])})
        metadata_dict.update({'mfcc'+str(i)+'_var':np.var(mfcc[i-1])})
    df_meta = pd.DataFrame(metadata_dict,index=[0])
    return df_meta

# %%
#Prediction Accuracy after hyperparameter tuning
grid_predictions_test = grid.predict(X_test)
print('accuracy score: ', accuracy_score(y_test,grid_predictions_test))
print('f1_score : ', f1_score(y_test,grid_predictions_test,average='micro'))
# Out:
# accuracy score:  0.8891855807743658
# f1_score :  0.8891855807743658

# %% [markdown]
# # XGBoost

# %%
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

import matplotlib.pyplot as plt

# %%
def plotTraining(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, acc, 'bo', label='Training_acc')
    plt.plot(epochs, val_acc, 'b', label='Validation_acc')
    plt.title('Training and validation accuracy')
    plt.legend() 

    plt.figure() 

    plt.plot(epochs, loss, 'bo', label='Training_loss')
    plt.plot(epochs, val_loss, 'b', label='Validation_loss')
    plt.title('Training and validation loss')
    plt.legend() 

    plt.show()

# %%
model_xgboost = xgboost.XGBClassifier(learning_rate=0.1,
                                      max_depth=5,
                                      n_estimators=5000,
                                      subsample=0.5,
                                      colsample_bytree=0.5,
                                      eval_metric='auc',
                                      verbosity=1)

eval_set = [(X_val, y_val)]

model_xgboost.fit(X_train,
                  y_train,
                  early_stopping_rounds=10,
                  eval_set=eval_set,
                  verbose=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       1 model_xgboost = xgboost.XGBClassifier(learning_rate=0.1,
#       2                                       max_depth=5,
#       3                                       n_estimators=5000,
#    (...)
#       6                                       eval_metric='auc',
#       7                                       verbosity=1)
#       9 eval_set = [(X_val, y_val)]
# ---> 11 model_xgboost.fit(X_train,
#      12                   y_train,
#      13                   early_stopping_rounds=10,
#      14                   eval_set=eval_set,
#      15                   verbose=True)
#
# File c:\Users\mohammed kaif\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# TypeError: XGBClassifier.fit() got an unexpected keyword argument 'early_stopping_rounds'

# %%
# test_predict1 = model_xgboost.predict(df)
# print(test_predict1)

# %% [markdown]
# # Testing on New song

# %%
#df genration for new song
df=getdataf(r"C:\Users\mohammed kaif\Downloads\hhoho\Music_Genre_classification-2022-23-Project\audio.wav")
df = sc.transform(df)
print(df)
test_predict = grid.predict(df)
print(test_predict)
# Out:
# C:\Users\mohammed kaif\AppData\Local\Temp\ipykernel_2400\1568602305.py:10: FutureWarning: librosa.beat.tempo
# 	This function was moved to 'librosa.feature.rhythm.tempo' in librosa version 0.10.0.
# 	This alias will be removed in librosa version 1.0.
#   tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 #df genration for new song
# ----> 2 df=getdataf(r"C:\Users\mohammed kaif\Downloads\hhoho\Music_Genre_classification-2022-23-Project\audio.wav")
#       3 df = sc.transform(df)
#       4 print(df)
#
# Cell In[17], line 15, in getdataf(filename)
#      12 #fetching beats
#      14 y_harmonic, y_percussive = librosa.effects.hpss(y)
# ---> 15 tempo, beat_frames = librosa.beat.beat_track(y=y_percussive,sr=sr)
#      17 #chroma_stft
#      19 chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
#
# File c:\Users\mohammed kaif\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\beat.py:185, in beat_track(y, sr, onset_envelope, hop_length, start_bpm, tightness, trim, bpm, prior, units)
#     176     bpm = _tempo(
#     177         onset_envelope=onset_envelope,
#     178         sr=sr,
#    (...)
#     181         prior=prior,
#     182     )[0]
#     184 # Then, run the tracker
# --> 185 beats = __beat_tracker(onset_envelope, bpm, float(sr) / hop_length, tightness, trim)
#     187 if units == "frames":
#     188     return (bpm, beats)
#
# File c:\Users\mohammed kaif\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\beat.py:433, in __beat_tracker(onset_envelope, bpm, fft_res, tightness, trim)
#     430 beats = np.array(beats[::-1], dtype=int)
#     432 # Discard spurious trailing beats
# --> 433 beats = __trim_beats(localscore, beats, trim)
#     435 return beats
#
# File c:\Users\mohammed kaif\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\beat.py:507, in __trim_beats(localscore, beats, trim)
#     505 def __trim_beats(localscore: np.ndarray, beats: np.ndarray, trim: bool) -> np.ndarray:
#     506     """Remove spurious leading and trailing beats"""
# --> 507     smooth_boe = scipy.signal.convolve(localscore[beats], scipy.signal.hann(5), "same")
#     509     if trim:
#     510         threshold = 0.5 * ((smooth_boe**2).mean() ** 0.5)
#
# AttributeError: module 'scipy.signal' has no attribute 'hann'

# %%
test_predict1 = model_xgboost.predict(df)
print(test_predict1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 test_predict1 = model_xgboost.predict(df)
#       2 print(test_predict1)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Stacking the Models

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

estimator_list = [
    ('model_xgboost',model_xgboost),
    ('grid',grid)
]

#Build Stack Model

StackModel = StackingClassifier(estimators = estimator_list,final_estimator = LogisticRegression())

StackModel.fit(X_train,y_train)

#Prediction by Ensembled Model
Stack_model_pred = StackModel.predict(X_val)
print('accuracy score: ', accuracy_score(y_val,Stack_model_pred))
print('f1_score : ', f1_score(y_val,Stack_model_pred,average='micro'))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.159 total time=   7.4s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.150 total time=   7.3s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.167 total time=   7.3s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.153 total time=   7.3s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.152 total time=   7.3s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.867 total time=   2.2s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.858 total time=   2.2s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.859 total time=   2.2s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.870 total time=   2.2s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.862 total time=   2.2s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.469 total time=   6.6s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.456 total time=   6.6s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.455 total time=   6.6s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.472 total time=   6.6s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.471 total time=   6.6s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.868 total time=   2.2s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.861 total time=   2.2s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.864 total time=   2.2s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.866 total time=   2.2s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.870 total time=   2.2s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.261 total time=   8.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.255 total time=   8.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.249 total time=   8.1s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.234 total time=   8.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.237 total time=   8.1s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.867 total time=   2.2s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.858 total time=   2.2s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.859 total time=   2.2s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0

# [CV 2/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.852 total time=   1.5s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.837 total time=   1.5s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.854 total time=   1.5s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.848 total time=   1.5s
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# accuracy score:  0.9026666666666666
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27/4032263910.py in <module>
#      16 Stack_model_pred = StackModel.predict(X_val)
#      17 print('accuracy score: ', accuracy_score(y_val,Stack_model_pred))
# ---> 18 print('f1_score : ', f1_score(y_test,Stack_model_pred,average='micro'))
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1129         average=average,
#    1130         sample_weight=sample_weight,
# -> 1131         zero_division=zero_division,
#    1132     )
#    1133
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1268         warn_for=("f-score",),
#    1269         sample_weight=sample_weight,
# -> 1270         zero_division=zero_division,
#    1271     )
#    1272     return f
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
#    1543         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1545
#    1546     # Calculate tp_sum, pred_sum, true_sum ###
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [749, 750]

# %%
print('accuracy score: ', accuracy_score(y_val,Stack_model_pred))
print('f1_score : ', f1_score(y_val,Stack_model_pred,average='micro'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print('accuracy score: ', accuracy_score(y_val,Stack_model_pred))
#       2 print('f1_score : ', f1_score(y_val,Stack_model_pred,average='micro'))
#
# NameError: name 'Stack_model_pred' is not defined

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 0.1, 'gamma': 0.1, 'kernel': 'poly'}
# SVC(C=0.1, gamma=0.1, kernel='poly')

# %%
print(StackModel.predict(df))
# Out:
# [4]

# %%
#Saving the model
from joblib import Parallel, delayed
import joblib
  
  
#Save the Model using pickle
joblib.dump(StackModel, 'final.pkl')
  
# Load the model from the file
Model_from_joblib = joblib.load('final.pkl')
  
# Use the loaded model to make predictions
Model_from_joblib.predict(X_val)
# Out:
# array([6, 6, 9, 4, 4, 4, 5, 4, 7, 8, 6, 3, 2, 8, 0, 9, 8, 5, 1, 0, 7, 7,
#        2, 0, 6, 1, 3, 9, 5, 7, 0, 4, 8, 8, 7, 6, 0, 8, 8, 6, 3, 5, 0, 1,
#        2, 5, 4, 5, 1, 1, 1, 1, 4, 3, 8, 0, 0, 7, 1, 0, 1, 0, 4, 9, 2, 6,
#        5, 7, 8, 2, 2, 5, 6, 1, 0, 6, 1, 0, 1, 1, 0, 1, 1, 2, 7, 8, 1, 9,
#        9, 5, 6, 2, 8, 6, 5, 6, 6, 5, 5, 9, 9, 1, 4, 4, 5, 6, 9, 0, 6, 5,
#        1, 0, 1, 3, 2, 6, 9, 0, 4, 5, 1, 0, 0, 1, 1, 6, 1, 5, 7, 4, 3, 8,
#        6, 8, 7, 6, 2, 2, 9, 4, 6, 4, 8, 8, 0, 0, 0, 1, 3, 7, 4, 5, 5, 4,
#        8, 3, 5, 2, 9, 8, 1, 0, 1, 7, 9, 3, 4, 7, 2, 9, 8, 5, 1, 0, 3, 0,
#        3, 3, 2, 0, 8, 2, 1, 0, 7, 5, 9, 5, 2, 4, 1, 7, 0, 1, 4, 8, 0, 4,
#        8, 4, 9, 3, 4, 4, 7, 7, 1, 9, 1, 3, 0, 2, 8, 5, 9, 5, 8, 3, 0, 3,
#        3, 6, 5, 1, 4, 3, 9, 2, 7, 4, 2, 7, 2, 5, 7, 7, 4, 6, 9, 2, 6, 9,
